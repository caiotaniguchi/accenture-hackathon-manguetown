# %%
import pandas as pd
import numpy as np

import os
import sys
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import time

from sklearn.cluster import KMeans

# %%
cc_data = pd.read_excel('default of credit card clients.xls', skiprows=[0])
cc_data.set_index(['ID'], inplace=True)
print (cc_data.shape)
# Out:
# (30000, 24)

# %%
cc_data['EDUCATION'].loc[cc_data['EDUCATION'] > 4] = 4
cc_data['EDUCATION'].loc[cc_data['EDUCATION'] == 0] = 4

# %%
cc_data.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
#
#     PAY_5             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID                    ...
# 1      -2             ...                      0          0          0
# 2       0             ...                   3272       3455       3261
# 3       0             ...                  14331      14948      15549
# 4       0             ...                  28314      28959      29547
# 5       0             ...                  20940      19146      19131
#
#     PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
cc_data.loc[cc_data['EDUCATION'] == 0]
# Out:
# Empty DataFrame
# Columns: [LIMIT_BAL, SEX, EDUCATION, MARRIAGE, AGE, PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6, BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6, PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6, default payment next month]
# Index: []
#
# [0 rows x 24 columns]

# %%
len(cc_data.index)
# Out:
# 30000

# %%
#Gender (1 = male; 2 = female). 
df_M = cc_data.loc[cc_data['SEX'] == 1]
df_F = cc_data.loc[cc_data['SEX'] == 2]

df_F
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 8         100000    2          2         2   23      0     -1     -1      0
# 9         140000    2          3         1   28      0      0      2      0
# 11        200000    2          3         2   34      0      0      2      0
# 12        260000    2          1         2   51     -1     -1     -1     -1
# 13        630000    2          2         2   41     -1      0     -1     -1
# 16         50000    2          3         3   23      1      2      0      0
# 19        360000    2          1         1   49      1     -2     -2     -2
# ...

# %%
len(df_M.index) + len(df_F.index)
# Out:
# 30000

# %%
#Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).

# %%
#male
#string = "Bachelors,Some-college,11th,HS-grad,Prof-school,Assoc-acdm,Assoc-voc,9th,7th-8th,12th,Masters,1st-4th,10th,Doctorate,5th-6th,Preschool"

#l = string.split(",")
l = [1,2,3,4]
print(l)
l_dfs_M = []
for i in l:
    l_dfs_M.append(df_M.loc[df_M['EDUCATION'] == i])
l_dfs_M[2].head()
# Out:
# [1, 2, 3, 4]
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 10      20000    1          3         2   35     -2     -2     -2     -2
# 26      50000    1          3         2   23      0      0      0      0
# 51      70000    1          3         2   42      1      2      2      2
# 77      50000    1          3         2   25     -1      0      0      0
# 83      60000    1          3         2   30      0      0      0      0
#
#     PAY_5             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID                    ...
# 10     -1             ...                      0      13007      13912
# 26      0             ...                  28967      29829      30046
# 51      2             ...                  39423      38659      39362
# 77      0             ...                   9636       9590      10030
# 83      0             ...                  21993      19899      19771
#
# ...

# %%
#female
l_dfs_F = []
for i in l:
    l_dfs_F.append(df_F.loc[df_F['EDUCATION'] == i])
l_dfs_F[0].head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 12     260000    2          1         2   51     -1     -1     -1     -1
# 19     360000    2          1         1   49      1     -2     -2     -2
# 20     180000    2          1         2   29      1     -2     -2     -2
# 24     450000    2          1         1   40     -2     -2     -2     -2
# 31     230000    2          1         2   27     -1     -1     -1     -1
#
#     PAY_5             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID                    ...
# 12     -1             ...                   8517      22287      13668
# 19     -2             ...                      0          0          0
# 20     -2             ...                      0          0          0
# 24     -2             ...                    560          0          0
# 31     -1             ...                  15339      14307      36923
#
#     PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
#cc_data.loc[cc_data['EDUCATION'] == 0]

# %%
#np.random.binomial(1, male_prior, size=300)

# %%
ad = pd.read_csv('adult.data.txt', header=None)
ad.shape
ad['annual_revenue_above_50k'] = ad[14].str.contains('>')
ad.annual_revenue_above_50k
ad['annual_revenue_above_50k'].hist(by=ad[9])
plt.show()
groups_gender = ad.groupby(by=9)['annual_revenue_above_50k']
female_prior, male_prior = groups_gender.mean()
groups_education = ad.groupby(by=3)['annual_revenue_above_50k']
results = groups_education.mean()
results
male_with_education_prior = male_prior * results
female_with_education_prior = female_prior * results

male_with_education_prior.plot.bar()
plt.title('Male prior to earn more than 50k per year')
plt.show()

# %%
#1 = graduate school; 2 = university; 3 = high school; 4 = others
# graduate school = Bachelors, doctorate, masters,
# university = some-college, 
# high school = HS-grad,
# others =
dic_m = male_with_education_prior.to_dict()
dic_m
# Out:
# {' 10th': 0.020316900040186776,
#  ' 11th': 0.015612080497593077,
#  ' 12th': 0.02330094000362477,
#  ' 1st-4th': 0.010919163443257064,
#  ' 5th-6th': 0.014690045713450945,
#  ' 7th-8th': 0.018931057362922464,
#  ' 9th': 0.016060092535218562,
#  ' Assoc-acdm': 0.075932701732865426,
#  ' Assoc-voc': 0.079863172275283945,
#  ' Bachelors': 0.12680503010443889,
#  ' Doctorate': 0.22652637380587534,
#  ' HS-grad': 0.048767618844753481,
#  ' Masters': 0.17016911014413155,
#  ' Preschool': 0.0,
#  ' Prof-school': 0.22452529830197338,
#  ' Some-college': 0.058161655668952317}

# %%
graduateschool = dic_m[' Bachelors'] + dic_m[' Doctorate'] + dic_m[' Masters'] + dic_m[' Prof-school']
university = dic_m[' Some-college']
highschool = dic_m[' HS-grad']
others = dic_m[' Assoc-acdm']+dic_m[' Assoc-voc']+dic_m[' 10th']+dic_m[ ' 11th']+dic_m[' 12th']+dic_m[' 1st-4th']+dic_m[' 5th-6th']+ dic_m[' 7th-8th']+dic_m[' 9th']

# %%
l_prior_m = [graduateschool,university,highschool,others]
l_prior_m
# Out:
# [0.74802581235641918,
#  0.058161655668952317,
#  0.048767618844753481,
#  0.27562615360440301]

# %%
for x in range(len(l)):
    prior = l[x]
    sz = len(l_dfs_M[x].index)
    temp_dis = np.random.binomial(1, l_prior_m[x], size=sz)
    l_dfs_M[x]['above50k'] = pd.Series(temp_dis, index= l_dfs_M[x].index)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
l_dfs_M[0]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 6          50000    1          1         2   37      0      0      0      0
# 7         500000    1          1         2   29      0      0      0      0
# 15        250000    1          1         2   29      0      0      0      0
# 17         20000    1          1         2   24      0      0      2      2
# 18        320000    1          1         1   49      0      0      0     -1
# 25         90000    1          1         2   23      0      0      0     -1
# 27         60000    1          1         2   27      1     -2     -1     -1
# 30         50000    1          1         2   26      0      0      0      0
# 33        100000    1          1         2   32      0      0      0      0
# 35        500000    1          1         1   58     -2     -2     -2     -2
# 36        160000    1          1         2   30     -1     -1     -2     -2
# ...

# %%
female_with_education_prior.plot.bar()
plt.title('Female prior to earn more than 50k per year')
plt.show()

# %%
dic_f = female_with_education_prior.to_dict()
dic_f
# Out:
# {' 10th': 0.0072739083540088144,
#  ' 11th': 0.0055894768655787705,
#  ' 12th': 0.0083422619500699308,
#  ' 1st-4th': 0.0039093067363422948,
#  ' 5th-6th': 0.0052593676212653101,
#  ' 7th-8th': 0.0067777454252374155,
#  ' 9th': 0.0057498752775773836,
#  ' Assoc-acdm': 0.027185619478594027,
#  ' Assoc-voc': 0.028592816563638147,
#  ' Bachelors': 0.045399060190411698,
#  ' Doctorate': 0.081101549920050323,
#  ' HS-grad': 0.017459907240686946,
#  ' Masters': 0.060924378690808648,
#  ' Preschool': 0.0,
#  ' Prof-school': 0.080385119766038446,
#  ' Some-college': 0.020823184256287118}

# %%
graduateschool_f = dic_f[' Bachelors'] + dic_f[' Doctorate'] + dic_f[' Masters'] + dic_f[' Prof-school']
university_f = dic_f[' Some-college']
highschool_f = dic_f[' HS-grad']
others_f = dic_f[' Assoc-acdm']+dic_f[' Assoc-voc']+dic_f[' 10th']+dic_f[ ' 11th']+dic_f[' 12th']+dic_f[' 1st-4th']+dic_f[' 5th-6th']+ dic_f[' 7th-8th']+dic_f[' 9th']

l_prior_f = [graduateschool_f,university_f,highschool_f,others_f]
l_prior_f
# Out:
# [0.26781010856730914,
#  0.020823184256287118,
#  0.017459907240686946,
#  0.098680378272312089]

# %%
for x in range(len(l)):
    prior = l[x]
    sz = len(l_dfs_F[x].index)
    temp_dis = np.random.binomial(1, l_prior_f[x], size=sz)
    l_dfs_F[x]['above50k'] = pd.Series(temp_dis, index= l_dfs_F[x].index)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
l_dfs_F[0]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 12        260000    2          1         2   51     -1     -1     -1     -1
# 19        360000    2          1         1   49      1     -2     -2     -2
# 20        180000    2          1         2   29      1     -2     -2     -2
# 24        450000    2          1         1   40     -2     -2     -2     -2
# 31        230000    2          1         2   27     -1     -1     -1     -1
# 42         70000    2          1         2   25      0      0      0      0
# 45         40000    2          1         2   30      0      0      0      2
# 47         20000    2          1         2   22      0      0      2     -1
# 54        180000    2          1         2   25      1      2      0      0
# 55        150000    2          1         2   29      2      0      0      0
# 56        500000    2          1         1   45     -2     -2     -2     -2
# ...

# %%
import itertools
concat = itertools.chain(l_dfs_F, l_dfs_M)
df_above = pd.concat(concat)
df_above
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 12        260000    2          1         2   51     -1     -1     -1     -1
# 19        360000    2          1         1   49      1     -2     -2     -2
# 20        180000    2          1         2   29      1     -2     -2     -2
# 24        450000    2          1         1   40     -2     -2     -2     -2
# 31        230000    2          1         2   27     -1     -1     -1     -1
# 42         70000    2          1         2   25      0      0      0      0
# 45         40000    2          1         2   30      0      0      0      2
# 47         20000    2          1         2   22      0      0      2     -1
# 54        180000    2          1         2   25      1      2      0      0
# 55        150000    2          1         2   29      2      0      0      0
# 56        500000    2          1         1   45     -2     -2     -2     -2
# ...
